# %%
from pathlib import Path
import sys

# Make src/ imports work whether Jupyter is opened from the project root
# or from inside the notebooks/ folder.
PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from IPython.display import Audio, display

from src.config import ARTIFACTS_DIR
from src.text_to_speech import clean_caption_for_speech, text_to_speech

# %%
# Option 1: Use a caption generated in notebook 08 if it is available.
# Option 2: Use this sample caption so this notebook can run by itself.

# get caption text
try:
    caption_text = clean_caption_for_speech(pred)
except NameError:
    caption_text = "two dogs are swimming in the water"

print("Predicted Caption:", caption_text)
# Out:
# Predicted Caption: two dogs are swimming in the water

# %% [markdown]
# ## Generate Audio

# %%
audio_path = ARTIFACTS_DIR / "predicted_caption.mp3"

try:
    audio_path = text_to_speech(caption_text, audio_path=audio_path, lang="en")
    print("Audio saved at:", audio_path)
except Exception as error:
    print("Audio generation failed.")
    print("Reason:", error)
    print("Check that gTTS is installed and internet is available.")
# Out:
# Audio saved at: /Users/mitpatel/Desktop/ImageCaptionGenerator/artifacts/predicted_caption.mp3

# %%
# Play audio
if Path(audio_path).exists():
    print("Playing predicted caption audio:")
    display(Audio(str(audio_path), autoplay=True))
else:
    print("Audio file was not created yet.")
# Out:
# Playing predicted caption audio:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
